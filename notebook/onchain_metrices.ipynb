# %%
from modules.onchain.metrics.aggregator import combine_metrics
from modules.onchain.metrics.exchange_flows import compute_exchange_flows
from modules.onchain.metrics.whale_alerts import summarize_whale_alerts

# %%
whales = summarize_whale_alerts(chain="ethereum", time_window="24h")
whales
# Out:
# {"timestamp": "2025-11-12 18:57:26,841", "level": "INFO", "message": "Returning cached whale summary for onchain:whale_alerts:ethereum:24h", "module": "whale_alerts", "function": "summarize_whale_alerts", "line": 35}
# {'time': '2025-11-12T13:20:59.006552+00:00',
#  'chain': 'ethereum',
#  'window': '24h',
#  'whale_count': 290,
#  'total_whale_volume_usd': 35843733335.631256,
#  'avg_whale_tx_size_usd': 123599080.46769398,
#  'whale_exchange_inflow': 16,
#  'whale_exchange_outflow': 7,
#  'whale_exchange_ratio': 69.56521739130434,
#  'unique_whale_addresses': 185}

# %%
flows = compute_exchange_flows(chain="ethereum", time_window="24h")
flows
# Out:
# {"timestamp": "2025-11-12 18:57:26,878", "level": "INFO", "message": "Returning cached exchange flows for onchain:exchange_flows:ethereum:24h", "module": "exchange_flows", "function": "compute_exchange_flows", "line": 34}
# {'time': '2025-11-12T13:20:58.968264+00:00',
#  'chain': 'ethereum',
#  'window': '24h',
#  'exchange_inflow_usd': 208068621.58370757,
#  'exchange_outflow_usd': 5270570974.911022,
#  'net_flow_usd': 5062502353.327315,
#  'exchange_flow_ratio': 92.40436908035231,
#  'flow_trend_24h': 0.0}

# %%
agg = combine_metrics(chain="ethereum", time_window="24h", symbol="BTC")
agg
# Out:
# {"timestamp": "2025-11-12 18:57:26,926", "level": "INFO", "message": "Returning cached aggregated metrics for onchain:aggregated_metrics:ethereum:24h:BTC", "module": "aggregator", "function": "combine_metrics", "line": 34}
# {'time': '2025-11-12T13:26:13.523677+00:00',
#  'chain': 'ethereum',
#  'window': '24h',
#  'symbol': 'BTC',
#  'market_pressure_index': 0,
#  'whale_to_exchange_ratio': 1.6,
#  'price_whale_corr_7d': nan,
#  'flow_trend_7d': 0.0,
#  'market_bias': 'neutral',
#  'price_change_pct': 0.0,
#  'ta_bias': -1}
