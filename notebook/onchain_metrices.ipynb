# %%
from modules.onchain.metrics.aggregator import combine_metrics
from modules.onchain.metrics.exchange_flows import compute_exchange_flows
from modules.onchain.metrics.whale_alerts import summarize_whale_alerts

# %%
whales = summarize_whale_alerts(chain="ethereum", time_window="24h")
whales
# Out:
# {"timestamp": "2025-11-04 23:06:40,485", "level": "INFO", "message": "Returning cached whale summary for onchain:whale_alerts:ethereum:24h", "module": "whale_alerts", "function": "summarize_whale_alerts", "line": 35}
# {'time': '2025-11-04T17:28:39.376420+00:00',
#  'chain': 'ethereum',
#  'window': '24h',
#  'whale_count': 0,
#  'total_whale_volume_eth': 0.0,
#  'avg_whale_tx_size_eth': 0.0,
#  'whale_exchange_inflow': 0,
#  'whale_exchange_outflow': 0,
#  'whale_exchange_ratio': 0.0,
#  'unique_whale_addresses': 0}

# %%
flows = compute_exchange_flows(chain="ethereum", time_window="24h")
flows
# Out:
# {"timestamp": "2025-11-04 23:07:00,009", "level": "INFO", "message": "Returning cached exchange flows for onchain:exchange_flows:ethereum:24h", "module": "exchange_flows", "function": "compute_exchange_flows", "line": 34}
# {'time': '2025-11-04T17:30:16.823137+00:00',
#  'chain': 'ethereum',
#  'window': '24h',
#  'exchange_inflow_eth': 0.0,
#  'exchange_outflow_eth': 0.0,
#  'net_flow_eth': 0.0,
#  'exchange_flow_ratio': 0.0,
#  'flow_trend_24h': 0.0}

# %%
agg = combine_metrics(chain="ethereum", time_window="24h", symbol="BTC")
agg
# Out:
# {"timestamp": "2025-11-04 23:07:02,432", "level": "INFO", "message": "Returning cached aggregated metrics for onchain:aggregated_metrics:ethereum:24h:BTC", "module": "aggregator", "function": "combine_metrics", "line": 34}
# {'time': '2025-11-04T17:30:16.896045+00:00',
#  'chain': 'ethereum',
#  'window': '24h',
#  'symbol': 'BTC',
#  'market_pressure_index': 0.3333333333333333,
#  'whale_to_exchange_ratio': 0.0,
#  'price_whale_corr_7d': 0.0,
#  'flow_trend_7d': 0.0,
#  'market_bias': 'neutral',
#  'price_change_pct': 0.0,
#  'ta_bias': -1}
